# %% [markdown]
# ## Recap Exercises

# %% [markdown]
# ## 📋 Quick Recap:
#
# 1. What does `"Python"[::-1]` return?
# 2. How do you access the last item in a list?
# 3. How do you count the number of items in a list?
# 4. What does `mylist.append("hello")` do?
# 5. What does `len("Welcome")` return?

# %%
'''
1. how does the following functions work in list
    a. append()
    b. extend()
    c. insert()
2. Given a list with numbers from 1 to 50 [1, 2, 3, 4, ..... 50]
    a. print multiples of 10 in reverse         Slicing: [start:end:step]
    b. reverse the list
    c. what is the index of the number 43
    d. how can we find the index of 43 imagine you don't know the order
3. If we have a string, s = "Amazingly" what will be the output of the following:
    a. s[3] =>
    b. s[2:] =>
    c. s[::-2] =>
    d. s[:7:3] =>

'''
# Out:
# '\n1. how does the following functions work in list\n    a. append()\n    b. extend()\n    c. insert()\n2. Given a list with numbers from 1 to 50 [1, 2, 3, 4, ..... 50]\n    a. print multiples of 10 in reverse         Slicing: [start:end:step]\n    b. reverse the list\n    c. what is the index of the number 43\n    d. how can we find the index of 43 imagine you don\'t know the order\n3. If we have a string, s = "Amazingly" what will be the output of the following:\n    a. s[3] => \n    b. s[2:] => \n    c. s[::-2] => \n    d. s[:7:3] => \n\n'

# %% [markdown]
# 4. Given the list:
# ```python
# fruits = ["apple", "banana", "cherry"]
# ```
# `write the code below in the provided space for each question`

# %%
fruits = ["apple", "banana", "cherry"]
# 1. how can we change the second item to "Avocado" instead of "banana"


print(fruits) #it should look like ['apple', 'Avocado', 'cherry']

# %%
# 2. in the above list fruits add "strawberry" at the end of the list

print(fruits) #it should look like ['apple', 'Avocado', 'cherry', 'strawberry']

# %%
# 3. add ["Watermelon", "Papaya"] to the fruits list .. hint: use .extend() not .append()

print(fruits) # it should look like ['apple', 'Avocado', 'cherry', 'strawberry', "Watermelon", "Papaya"]

# %% [markdown]
# 5. If we have list,
# ```python
# mylist = [1, 2, 3, 4, 5, 6]
# ```
# `write code for each of the following questions below`

# %%
mylist = [1, 2, 3, 4, 5, 6]
# multiply the 3rd number with the 5th number

print(...) #you should get 15

# %%
# swap the 3rd and the 5th number i.e, after swapping, the list will look like: [1, 2, 5, 4, 3, 6]


print(mylist) # you should get [1, 2, 5, 4, 3, 6]

# %% [markdown]
# ## One more Lesson
# How to make string all upper case and lowercase?
#
#
# *   we use .upper() to make string uppercase
# *   we use .lower() to make string lowercase

# %%
name = "Henok"
#change it to upper case
print(name.upper())
#change it to lower case
print(name.lower())
# Out:
# HENOK
# henok

# %%
#try it yourself

#ask user for their name
username = input("Please insert your name: ")
upperName = username.upper()
lowerName = username.lower()
print(upperName, lowerName)
# Out:
# Please insert your name: eyobed
# EYOBED eyobed

# %% [markdown]
# # Today's Exercises

# %% [markdown]
# ### Reverse a string using slicing

# %%
word = input("Enter a word: ") #taking input
reversed_word = word[::-1] #reversing the word and putting it in variable named reversed_word
print("Reversed word:", reversed_word) #printing hte reversed word
# Out:
# Enter a word: happy
# Reversed word: yppah

# %%
#your trial here

#ask user their favorite subject

#reverse it and put it in a varialbe named

#print the reversed word

# %% [markdown]
# ### Palindrome Check
#
# Palindrome is a word that is read the same both forward and backwards.
#
# Example: racecar, civil, level, madam...

# %% [markdown]
# Write a code that take input from user and check if it is palindrome
#
# `hint: use '==' comparator to check`
#
# Example:
# ```python
# name = input("insert your name: ")
# reversed_name = name[::-1]
# #checking if the reversed and orginal are the same
# print(name == reversed_name)
# ```

# %%
#write your code here

#Ask user for any word

#reverse the word and put it in a variable of your choice

#check if the word is palindrome

# %% [markdown]
# ### 3. Secret Code Generator
#
# You're going to build a secret message tool!
#
# The user types in a normal sentence, and your program turns it into a **secret code** by:
# - Removing all spaces
# - Reversing the message
# - Turning it into ALL CAPS(meaning all capital letters)
#
# Let's build it step by step.

# %%
sentence = "How are you?"
sentence[4]
# Out:
# 'a'

# %%
firstPart = sentence[0:3]
firstPart
# Out:
# 'How'

# %%
secondPart = sentence[4:7]
secondPart
# Out:
# 'are'

# %%
lastPart = sentence[8:]
lastPart
# Out:
# 'you?'

# %%
together = firstPart + secondPart + lastPart
together
# Out:
# 'Howareyou?'

# %%
#reverse
reversed = together[::-1]
reversed
# Out:
# '?uoyerawoH'

# %%
secretMessage = reversed.upper()
secretMessage
# Out:
# '?UOYERAWOH'

# %%
# Step 1: Ask the user for a message

# Write your code here:
message = input("Write a sentence: ")
# Out:
# Write a sentence: Today is very cold.

# %%
message
# Out:
# 'Today is very cold.'

# %%
# Step 2: Transform it into a secret code

# Remove spaces
removedSpace = message[:5] + message[6:8] + message[9:13] + message[14:]
print(removedSpace)
# Reverse the message
reversed = removedSpace[::-1]
# Convert to uppercase
secret = reversed.upper()
# no_spaces = ...
# reversed_msg = ...
# secret_code = ...

# Print result
print(secret)
# Out:
# Todayisverycold.
# .DLOCYREVSIYADOT

# %%
# Step 3: Show the original and the secret version

print("===================")
print("ORIGINAL MESSAGE:")
print(message)

print("\nSECRET CODE:")
print(secret_code)
print("===================")
