# %% [markdown]
# # Recap Exercises

# %%
'''
    9. ask user three numbers, print the largest from these 3
'''

# %%
'''
    1. how do we type cast to integer type?
    2. ask user to enter a number and print "positive" if it's positive,"negative" if it s negative or "zero" if it is 0
    3. Is it must to have elif or else conditions?
    4. what is the difference between for loop and while loop?
'''
# Out:
# '\n    1. how do we type cast to integer type?\n    2. ask user to enter a number and print "positive" if it\'s positive,"negative" if it s negative or "zero" if it is 0\n    3. Is it must to have elif or else conditions?\n    4. what is the difference between for loop and while loop?\n'

# %% [markdown]
# `print the word 'hello' 50 times using for loop`

# %%
#write your code here

# %% [markdown]
# # Guided practice

# %% [markdown]
# `Exercise 1:` Odd or Even Checker

# %% [markdown]
# your code should do the following
# ```
# 1. Take input number (remember to type cast)
# 2. check if it is even or odd
# 3. if it is even print "even"
# 4. if it is odd print "odd"
# ```
#
# For example
# ```python
# num = 34 #the user entered 34
# #it should print: "even"
# ```

# %%
# ask user to enter a number let's call it num
num = int(input("Enter a number :"))

#write you code below to check if a number is even or odd and print

# %% [markdown]
# `Exercise 2:` Grade Evaluator

# %% [markdown]
# Your program must do the following
#
#
# ```
# 1. Ask user their grade
# 2. print 'A' if grade is between 90 & 100
# 3. print 'B' if grade is b/n 85 and 89
# 4. print 'C' if grade is b/n 80 and 84
# 5. print 'D' if grade is b/n 70 - 79
# 6. print 'F' otherwise
# ```
# For example:
# ```python
# score = 87
# #it will print 'B'
# ```

# %%
#let's have variable named score to store our value from user
score = float(input("Enter your exam score (0–100): ")) #remember  type casting is to float instead of int because grade can be decimal
# write your code below

# %% [markdown]
# `Exercise 3:` Update our Palidrome checker program from last lab

# %% [markdown]
# In our last lab, you have written a code to check if a given input is palindrome or no.
# In this lab, you will make it more exciting by using if conditional.
#
#
#
#
# ```
# Task:
# 1. Ask user string input
# 2. check if the string is palindrome or no
# 3. if it is palindrome, print "The word is palindrome"
# 4. else print "the word is not palindrome"
# ```

# %%
#let's take input as word
word = input("Enter a word: ")
#reverse it and put it in variable called 'reverse'
reverse = #write your code here
# Check if the word is equal to its reverse
#write your code below
# Out:
# Enter a word: madam

# %% [markdown]
# `Exercise 4:` using range function and for loop, print numbers from 1 to 10

# %%
#write your code here

# %% [markdown]
# `Exrcise 5:` ask user the start and end of range then print all numbers in that given range from start to end
#
# For example:
# ```python
# start = 2 #you need to ask the user
# end = 7 #again this is user input
# ```
# Then you should print all numbers from 2 to 7 using loop
